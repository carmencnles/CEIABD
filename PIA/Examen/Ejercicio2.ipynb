# %%
#2.1

import pandas as pd


df_nba = pd.read_csv("nba.csv")

# %%
# 2.2


if df_nba["G"] > 45 and df_nba["3P"] > 13:
    mayor45 = df_actualizado_nba = pd.DataFrame({"Probably_Died": mayor45})
    mayor13 = df_actualizado_nba = pd.DataFrame({"Probably_Died": mayor13})
print(mayor45)
print(mayor13)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_36005/2876802043.py in ?()
#       1 # 2.2
#       2
#       3
# ----> 4 if df_nba["G"] > 45 and df_nba["3P"] > 13:
#       5     mayor45= df_actualizado_nba = pd.DataFrame({"Probably_Died": mayor45})
#       6 print(mayor45)
#
# ~/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# 2.3

# %%
# 2.4

df_nba_nuevo = df_nba[["G","MP","FG","FGA","FG%","3P","3PA","3P%","2P","2PA","2P%","FT","FTA","FT%","ORB","DRB","TRB","AST","STL","BLK","TOV","PF"]]
print(type(df_nba_nuevo))
df_nba_nuevo.head()


df_nba_nuevo.corr(numeric_only=True).abs().sort_values(by= ["2P"], ascending=False).head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#             G        MP        FG       FGA       FG%        3P       3PA  \
# 2P   0.077412  0.220674  0.813984  0.480620  0.588684  0.605198  0.738197
# 2PA  0.131106  0.154904  0.557989  0.626534  0.170133  0.724915  0.800499
# FG   0.030144  0.201792  1.000000  0.543523  0.768017  0.030884  0.297225
# 3PA  0.212931  0.042684  0.297225  0.034507  0.309286  0.868544  1.000000
# 3P   0.172331  0.109071  0.030884  0.078794  0.037364  1.000000  0.868544
#
#           3P%        2P       2PA  ...       FTA       FT%       ORB  \
# 2P   0.110556  1.000000  0.864277  ...  0.180861  0.053278  0.065707
# 2PA  0.008241  0.864277  1.000000  ...  0.248813  0.034746  0.269088
# FG   0.468075  0.813984  0.557989  ...  0.088732  0.075099  0.145494
# 3PA  0.057485  0.738197  0.800499  ...  0.145622  0.345981  0.161896
# 3P   0.443144  0.605198  0.724915  ...  0.177662  0.189429  0.079950
#
# ...
