# %%
import os

base_path = 'dataset'

print("📁 Estructura del dataset:\n")

for item in os.listdir(base_path):
    item_path = os.path.join(base_path, item)
    if os.path.isdir(item_path):
        print(f"└── {item}/")
        subitems = os.listdir(item_path)[:10]  # Primeros 10 items
        for subitem in subitems:
            subitem_path = os.path.join(item_path, subitem)
            if os.path.isdir(subitem_path):
                n_files = len(os.listdir(subitem_path))
                print(f"    └── {subitem}/ ({n_files} archivos)")
            else:
                print(f"    └── {subitem}")
# Out:
# 📁 Estructura del dataset:
#
# └── images/
#     └── train/ (160 archivos)
#     └── val/ (37 archivos)
# └── labels/
#     └── train/ (157 archivos)
#     └── train.cache
#     └── val/ (35 archivos)
#     └── val.cache

# %%
from ultralytics import YOLO

# Usar modelo de segmentación en lugar de clasificación
model = YOLO('yolo11s-seg.pt')  # ← Cambio aquí: -seg en lugar de -cls

results = model.train(
    data='dataset/data.yaml',  
    epochs=50,
    imgsz=640,  # Tamaño típico para segmentación
    batch=16,
    name='segmentacion_exp'
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.7 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.1  Python-3.13.2 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=segmentacion_exp, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\Carmen\Documents\CURSO IA\CEIABD - Git\CEIABD\MIA\ActividadSegmentacion\runs\segment\segmentacion_exp, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1   1474678  ultralytics.nn.modules.head.Segment          [2, 32, 128, 16, None, [128, 256, 512]]
# YOLO11s-seg summary: 204 layers, 10,083,062 parameters, 10,083,046 gradients, 33.1 GFLOPs
#
# Transferred 555/561 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 2198.9809.0 MB/s, size: 1369.6 KB)
# train: Scanning C:\Users\Carmen\Documents\CURSO IA\CEIABD - Git\CEIABD\MIA\ActividadSegmentacion\dataset\labels\train.cache... 125 images, 35 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 160/160 51.6Mit/s 0.0s
# val: Fast image access  (ping: 0.20.1 ms, read: 835.2209.2 MB/s, size: 2303.9 KB)
# val: Scanning C:\Users\Carmen\Documents\CURSO IA\CEIABD - Git\CEIABD\MIA\ActividadSegmentacion\dataset\labels\val.cache... 25 images, 10 backgrounds, 2 corrupt: 100% ━━━━━━━━━━━━ 37/37 12.9Mit/s 0.0s
# val: C:\Users\Carmen\Documents\CURSO IA\CEIABD - Git\CEIABD\MIA\ActividadSegmentacion\dataset\images\val\IMG_6574.HEIC: ignoring corrupt image/label: cannot identify image file 'C:\\Users\\Carmen\\Documents\\CURSO IA\\CEIABD - Git\\CEIABD\\MIA\\ActividadSegmentacion\\dataset\\images\\val\\IMG_6574.HEIC'
# val: C:\Users\Carmen\Documents\CURSO IA\CEIABD - Git\CEIABD\MIA\ActividadSegmentacion\dataset\images\val\IMG_6575.HEIC: ignoring corrupt image/label: cannot identify image file 'C:\\Users\\Carmen\\Documents\\CURSO IA\\CEIABD - Git\\CEIABD\\MIA\\ActividadSegmentacion\\dataset\\images\\val\\IMG_6575.HEIC'
# Plotting labels to C:\Users\Carmen\Documents\CURSO IA\CEIABD - Git\CEIABD\MIA\ActividadSegmentacion\runs\segment\segmentacion_exp\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.001667, momentum=0.9) with parameter groups 0 weight(decay=0.0), 0 weight(decay=0.0005), 13 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to C:\Users\Carmen\Documents\CURSO IA\CEIABD - Git\CEIABD\MIA\ActividadSegmentacion\runs\segment\segmentacion_exp
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        1/50      4.94G     0.8979      2.529      4.219      1.105          0         56        640: 100% ━━━━━━━━━━━━ 10/10 1.0it/s 9.8s.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.7it/s 1.2s3.0s
#                    all         35         39      0.134      0.277      0.112     0.0788      0.147      0.277     0.0986     0.0667
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        2/50      4.82G     0.7483      2.006      3.467      1.031          0         40        640: 100% ━━━━━━━━━━━━ 10/10 1.7it/s 6.0s.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s1.5s
#                    all         35         39      0.299       0.59      0.335      0.267      0.299       0.59      0.327      0.244
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        3/50      5.98G     0.5577      1.357      2.341     0.9247          0         36        640: 100% ━━━━━━━━━━━━ 10/10 3.0it/s 3.3s.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s1.4s
#                    all         35         39      0.464      0.658      0.544      0.478      0.464      0.658      0.544      0.421
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        4/50      5.98G     0.4949       1.15      1.997     0.9127          0         57        640: 100% ━━━━━━━━━━━━ 10/10 3.3it/s 3.0s.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6
640: 100% ━━━━━━━━━━━━ 10/10 3.1it/s 3.3s.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.3it/s 0.3s0.9s
#                    all         35         39      0.782      0.669      0.768      0.728      0.782      0.669      0.768      0.685
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       42/50      5.06G     0.2421     0.5552      0.293     0.7797          0         21        640: 100% ━━━━━━━━━━━━ 10/10 5.0it/s 2.0s.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 8.2it/s 0.2s0.7s
#                    all         35         39      0.703      0.694       0.75      0.704      0.703      0.694       0.75      0.667
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       43/50      5.06G     0.2317     0.5436     0.2887     0.7845          0         20        640: 100% ━━━━━━━━━━━━ 10/10 5.2it/s 1.9s.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 8.1it/s 0.2s0.7s
#                    all         35         39      0.784      0.702      0.766      0.717      0.784      0.702      0.766      0.682
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       44/50      5.06G     0.2312     0.5478     0.2748     0.7692          0         29        640: 100% ━━━━━━━━━━━━ 10/10 5.0it/s 2.0s.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 8.0it/s 0.2s0.7s
#                    all         35         39      0.708       0.71      0.738      0.692      0.708       0.71      0.738      0.655
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       45/50      5.06G     0.2206     0.5382     0.2543     0.7895          0         22        640: 100% ━━━━━━━━━━━━ 10/10 5.2it/s 1.9s.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 8.3it/s 0.2s0.7s
#                    all         35         39      0.679      0.682      0.728      0.681      0.679      0.682      0.728      0.649
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       46/50      5.06G     0.2336     0.5543      0.265     0.7661          0         20        640: 100% ━━━━━━━━━━━━ 10/10 5.1it/s 2.0s.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 8.4it/s 0.2s0.7s
#                    all         35         39      0.692       0.68      0.727      0.676      0.692       0.68      0.727      0.646
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       47/50      5.06G     0.2366     0.5324     0.2576     0.7912          0         24        640: 100% ━━━━━━━━━━━━ 10/10 5.2it/s 1.9s.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 8.2it/s 0.2s0.7s
#                    all         35         39      0.707       0.68      0.727      0.678      0.707       0.68      0.727      0.644
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       48/50      5.06G     0.2332     0.5484     0.2598     0.7899          0         19        640: 100% ━━━━━━━━━━━━ 10/10 5.0it/s 2.0s.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 8.2it/s 0.2s0.7s
#                    all         35         39       0.72       0.71      0.746      0.694       0.72       0.71      0.746      0.662
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       49/50      5.06G     0.2194     0.5303     0.2535     0.7854          0         16        640: 100% ━━━━━━━━━━━━ 10/10 5.3it/s 1.9s.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 8.2it/s 0.2s0.7s
#                    all         35         39      0.722       0.71      0.747      0.695      0.722       0.71      0.747      0.664
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       50/50      5.06G     0.2155     0.5333     0.2319     0.7687          0         21        640: 100% ━━━━━━━━━━━━ 10/10 5.1it/s 2.0s.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 8.3it/s 0.2s0.7s
#                    all         35         39      0.683       0.71      0.742      0.691      0.683       0.71      0.742      0.655
#
# 50 epochs completed in 0.045 hours.
# Optimizer stripped from C:\Users\Carmen\Documents\CURSO IA\CEIABD - Git\CEIABD\MIA\ActividadSegmentacion\runs\segment\segmentacion_exp\weights\last.pt, 20.5MB
# Optimizer stripped from C:\Users\Carmen\Documents\CURSO IA\CEIABD - Git\CEIABD\MIA\ActividadSegmentacion\runs\segment\segmentacion_exp\weights\best.pt, 20.5MB
#
# Validating C:\Users\Carmen\Documents\CURSO IA\CEIABD - Git\CEIABD\MIA\ActividadSegmentacion\runs\segment\segmentacion_exp\weights\best.pt...
# Ultralytics 8.4.1  Python-3.13.2 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# YOLO11s-seg summary (fused): 114 layers, 10,067,590 parameters, 0 gradients, 32.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 8.1it/s 0.2s0.6s
#                    all         35         39      0.661      0.828      0.792      0.749      0.661      0.828      0.792      0.699
#              Playmobil         19         22      0.726      0.773      0.832      0.789      0.726      0.773      0.832      0.739
#             Superthing         12         17      0.596      0.882      0.752      0.708      0.596      0.882      0.752      0.658
# Speed: 0.1ms preprocess, 2.5ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to C:\Users\Carmen\Documents\CURSO IA\CEIABD - Git\CEIABD\MIA\ActividadSegmentacion\runs\segment\segmentacion_exp

# %%
import yaml

dataset_path = '/home/ciabd01/Documentos/CEIABD/MIA/ActividadSegmentacion/dataset'

# Detectar número de clases automáticamente desde las etiquetas
import os

label_file = os.path.join(dataset_path, 'labels/train', os.listdir(f'{dataset_path}/labels/train')[0])
with open(label_file, 'r') as f:
    classes = set()
    for line in f:
        class_id = int(line.split()[0])
        classes.add(class_id)

nc = len(classes)

# Crear el YAML
data_config = {
    'path': dataset_path,
    'train': 'images/train',
    'val': 'images/val',
    'nc': nc,
    'names': {i: f'clase_{i}' for i in range(nc)}  # Ajusta los nombres reales
}

yaml_path = os.path.join(dataset_path, 'data.yaml')
with open(yaml_path, 'w') as f:
    yaml.dump(data_config, f, sort_keys=False)

print(f"✓ Archivo data.yaml creado con {nc} clases")
print(f"📄 Ubicación: {yaml_path}")
# Out:
# ✓ Archivo data.yaml creado con 1 clases
# 📄 Ubicación: /home/ciabd01/Documentos/CEIABD/MIA/ActividadSegmentacion/dataset/data.yaml

# %%
import os
from IPython.display import Image, display
import pandas as pd
import matplotlib.pyplot as plt

# Ruta a resultados
exp_name = 'segmentacion_exp'
results_path = f'runs/segment/{exp_name}'

print(f"📁 Resultados en: {results_path}\n")

# 1. Mostrar imágenes principales
print("="*60)
print("📊 VISUALIZACIONES")
print("="*60)

imgs = {
    'Curvas de entrenamiento': 'results.png',
    'Predicciones de validación': 'val_batch0_pred.jpg',
    'Ground Truth': 'val_batch0_labels.jpg',
    'Matriz de confusión': 'confusion_matrix.png'
}

for titulo, archivo in imgs.items():
    path = f'{results_path}/{archivo}'
    if os.path.exists(path):
        print(f"\n{titulo}:")
        display(Image(filename=path, width=800))

# 2. Métricas finales
print("\n" + "="*60)
print("📈 MÉTRICAS FINALES")
print("="*60)

df = pd.read_csv(f'{results_path}/results.csv')
ultima_epoca = df.iloc[-1]

print(f"\nÉpoca final: {int(ultima_epoca['epoch'])}")
print(f"mAP50 (Detección): {ultima_epoca['metrics/mAP50(B)']:.4f}")
print(f"mAP50-95 (Detección): {ultima_epoca['metrics/mAP50-95(B)']:.4f}")
print(f"mAP50 (Segmentación): {ultima_epoca['metrics/mAP50(M)']:.4f}")
print(f"mAP50-95 (Segmentación): {ultima_epoca['metrics/mAP50-95(M)']:.4f}")

print("\n✅ ¡Entrenamiento completado!")
print(f"Mejor modelo guardado en: {results_path}/weights/best.pt")
# Out:
# 📁 Resultados en: runs/segment/segmentacion_exp
#
# ============================================================
# 📊 VISUALIZACIONES
# ============================================================
#
# Curvas de entrenamiento:
# Predicciones de validación:
# Ground Truth:
# Matriz de confusión:
# ============================================================
# 📈 MÉTRICAS FINALES
# ============================================================
#
# Época final: 50
# mAP50 (Detección): 0.7421
# mAP50-95 (Detección): 0.6911
# mAP50 (Segmentación): 0.7421
# mAP50-95 (Segmentación): 0.6553
#
# ✅ ¡Entrenamiento completado!
# Mejor modelo guardado en: runs/segment/segmentacion_exp/weights/best.pt

# %% [markdown]
# ¿Describe cuáles son los elementos que presentan mayor
# complejidad de etiquetado/segmentación?
# - Oclusión parcial -- Confusión entre objetos
# - Tamaño variable -- No detecta objetos pequeños
# - Iluminación -- Falsos negativos
# - Similitud entre clases -- Confusión de clases
# - Fondos complejos -- Bounding boxes incorrectos
# - Poses variadas -- No reconoce algunas poses
# - Objetos múltiples -- Detecta varios como uno
# - Bordes difusos -- Inconsistencia
# - Dataset desbalanceado -- Sesgo del modelo
