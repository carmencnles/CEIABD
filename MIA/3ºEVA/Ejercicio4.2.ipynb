# %%
# !pip install git+https://github.com/openai/whisper.git
# Aseguramos que tenemos ffmpeg (necesario para procesar audio)
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-dkvscng5
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-dkvscng5
#   Resolved https://github.com/openai/whisper.git to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install imageio-ffmpeg

# 2. Esto descarga el ejecutable de ffmpeg sin pedir permisos de admin
import imageio_ffmpeg
print(f"FFmpeg listo en: {imageio_ffmpeg.get_ffmpeg_exe()}")
# Out:
# ...
# FFmpeg listo en: /home/ciabd01/anaconda3/lib/python3.13/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2

# %%
# Instalamos whisper y una herramienta que descarga ffmpeg directamente
# !pip install git+https://github.com/openai/whisper.git
# !pip install static-ffmpeg

# Esto configura el comando ffmpeg para que Whisper lo encuentre sin error
import static_ffmpeg
static_ffmpeg.add_paths()

print("FFmpeg configurado correctamente.")
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-rvka5x8i
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-rvka5x8i
#   Resolved https://github.com/openai/whisper.git to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# FFmpeg configurado correctamente.

# %%
import whisper
import os
# Elegimos el modelo (puedes cambiar "base" por "small" o "medium" según tu PC/GPU)
model = whisper.load_model("base")
print("Modelo cargado correctamente.")
# Out:
# Modelo cargado correctamente.

# %%
# Cambia "salida.mp3" por el nombre de TU archivo real
audio_path = "podcast.mp3" 

if not os.path.exists(audio_path):
    print(f"Error: El archivo {audio_path} no existe.")
else:
    # Ahora Whisper procesará tu video real 
    result = model.transcribe(audio_path, verbose=False)
    print("-" * 30)
    print("TRANSCRIPCIÓN FINALIZADA")
    print("-" * 30)
    print(result["text"]) # Aquí aparecerá lo que dice tu video
# Out:
# Detected language: Spanish
# 100%|██████████| 68043/68043 [00:25<00:00, 2652.21frames/s]
# ------------------------------
# TRANSCRIPCIÓN FINALIZADA
# ------------------------------
# ...

# %%
# Paso 5: Guardar la transcripción en un archivo de texto 
nombre_salida = "transcripcion_resultado.txt" 

# Abrimos el archivo en modo escritura ("w") con codificación utf-8 [cite: 39]
with open(nombre_salida, "w", encoding="utf-8") as f:
    f.write(result["text"]) 

print(f"La transcripción se ha guardado en: {nombre_salida}")
# Out:
# La transcripción se ha guardado en: transcripcion_resultado.txt

# %%
# Opción Avanzada A del PDF [cite: 41, 42]
print("\n--- DETALLE POR SEGMENTOS ---")
for segment in result['segments']:
    start = segment['start'] 
    end = segment['end'] 
    text = segment['text'] 
    print(f"[{start:5.2f}s -> {end:5.2f}s] {text}")
# Out:
# --- DETALLE POR SEGMENTOS ---
# [ 0.00s ->  9.12s]  Bueno, vamos a empezar de mis favoritos David Evil y el pajarazo. A ver, David Evil, yo lo
# [ 9.12s -> 12.52s]  vamos con el juego. Yo creo que ha sido vuestro Frank, fue al Frankicio durante un año.
# [12.52s -> 15.64s]  Sí, sí, sí, sí, así es la misma vez de los…
# [15.64s -> 23.80s]  Sí, sí, sí, sí, sí, sí, sí, sí, sí, sí, sí, sí, sí, sí, sí, sí, sí, sí,
# [24.36s -> 30.12s]  primero, cómo es… cómo contactáis y cómo es en persona aparte de lo que vemos.
# [30.12s -> 33.76s]  Pues nosotros le juntacamos por TikTok y ya la conocí, ¿eh?
# [33.76s -> 37.88s]  Bueno, pues era como el típico freaky de Scorpio, ¿sabes cómo que…
# [37.88s -> 41.60s]  Sí, tenía algún video virado y 30 mil visitaje, a ti te llegaba.
# [41.60s -> 43.52s]  Vas tu decía, bueno, este tiene mucha arancia.
# [43.52s -> 47.88s]  Todo el extra es y la verdad que era David Evil y pajarazo en dos personajes, tú las ves
# ...

# %%
# Opción Avanzada B del PDF [cite: 52]
# Usamos el parámetro task="translate" [cite: 54]
result_en = model.transcribe(audio_path, task="translate") 
print("TRADUCCIÓN AL INGLÉS:")
print(result_en["text"])
# Out:
# TRADUCCIÓN AL INGLÉS:
# ...

# %%
# Opción Avanzada C del PDF [cite: 57]
result = model.transcribe(audio_path, language="es")
