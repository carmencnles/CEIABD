# %% [markdown]
# Enunciado
# Una empresa del sector tecnológico quiere estimar el salario mensual de sus empleados en función de
# distintas variables relacionadas con su perfil profesional. Para ello, se dispone de un conjunto de datos
# históricos que será utilizado para construir un modelo de regresión lineal.
# Herramienta
# Anaconda (Jupyter Notebook).
# Conjunto de datos
# Se proporciona un fichero llamado empleados.csv que contiene las siguientes variables:
# edad → Edad del empleado (años)
# experiencia → Años de experiencia laboral
# formacion → Nivel formativo (1 = FP, 2 = Grado, 3 = Máster)
# horas_extra → Número medio de horas extra mensuales
# salario → Salario mensual en euros (variable dependiente)
# Se pide
# Estudiar el proceso completo de creación de un modelo de regresión lineal.
# Aplicar técnicas básicas de análisis exploratorio de datos.
# Construir y evaluar un modelo predictivo.
# Interpretar los coeficientes obtenidos.

# %% [markdown]
# 1. Carga y exploración de datos
# Importa las librerías necesarias (pandas, numpy, matplotlib, sklearn).
# Carga el fichero empleados.csv.
# Muestra las primeras filas del conjunto de datos.
# Comprueba si existen valores nulos o inconsistencias.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

empleados = pd.read_csv("empleados_v2.0.csv")

empleados.head(5)

#empleados.isnull().sum()
# Out:
#    edad  experiencia  formacion  horas_extra  salario
# 0    50           24          1            0     2616
# 1    36            8          2            8     2372
# 2    29            2          3            5     1955
# 3    42           18          1           15     2852
# 4    40           19          1            2     2750

# %% [markdown]
# 2. Análisis exploratorio
# Calcula estadísticas descriptivas básicas.
# Representa gráficamente la relación entre las variables independientes y el salario.
# Comenta brevemente qué variables parecen tener mayor relación con el salario

# %%
import statistics as stat
import seaborn as sns
#Media, mediana, moda, desviación típica y CV.

#Media
media_edad = np.mean(empleados["edad"])
media_exp = np.mean(empleados["experiencia"])
media_formacion = np.mean(empleados["formacion"])
media_horas = np.mean(empleados["horas_extra"])
media_salario = np.mean(empleados["salario"])

#Mediana
mediana_edad = np.mean(empleados["edad"])
mediana_exp = np.mean(empleados["experiencia"])
mediana_formacion = np.mean(empleados["formacion"])
mediana_horas = np.mean(empleados["horas_extra"])
mediana_salario = np.mean(empleados["salario"])

#Moda
moda_edad = stat.mode(empleados["edad"])
moda_exp = stat.mode(empleados["experiencia"])
moda_formacion = stat.mode(empleados["formacion"])
moda_horas = stat.mode(empleados["horas_extra"])
moda_salario = stat.mode(empleados["salario"])

print(f"Media de edad: {media_edad}")
print(f"Media de experiencia: {media_exp}")
print(f"Media de formacion: {media_formacion}")
print(f"Media de horas extra: {media_horas}")
print(f"Media de salario: {media_salario}")

print(f"Mediana de edad: {mediana_edad}")
print(f"Mediana de experiencia: {mediana_exp}")
print(f"Mediana de formacion: {mediana_formacion}")
print(f"Mediana de horas extra: {mediana_horas}")
print(f"Mediana de salario: {mediana_salario}")

print(f"Moda de edad: {moda_edad}")
print(f"Moda de experiencia: {moda_exp}")
print(f"Moda de formacion: {moda_formacion}")
print(f"Moda de horas extra: {moda_horas}")
print(f"Media de salario: {moda_salario}")


sns.pairplot(empleados, x_vars=['edad', 'experiencia', 'formacion', 'horas_extra'], y_vars='salario', height=4, aspect=1, kind='reg')
plt.show()
# Out:
# Media de edad: 38.61666666666667
# Media de experiencia: 14.183333333333334
# Media de formacion: 1.85
# Media de horas extra: 9.416666666666666
# Media de salario: 2689.7833333333333
# Mediana de edad: 38.61666666666667
# Mediana de experiencia: 14.183333333333334
# Mediana de formacion: 1.85
# Mediana de horas extra: 9.416666666666666
# Mediana de salario: 2689.7833333333333
# Moda de edad: 23
# Moda de experiencia: 0
# Moda de formacion: 1
# Moda de horas extra: 2
# Media de salario: 2616

# %% [markdown]
# 3. Preparación de los datos
# Separa las variables independientes (X) y la variable dependiente (y).
# Divide el conjunto de datos en conjunto de entrenamiento y de prueba (por ejemplo, 80 % / 20 %).
# Justifica brevemente por qué es necesaria esta división.

# %% [markdown]
# 4. Construcción del modelo
# Crea un modelo de regresión lineal.
# Entrena el modelo con los datos de entrenamiento.
# Muestra la ecuación del modelo obtenido

# %%
modelo = LinearRegression

# %% [markdown]
# 5. Evaluación del modelo
# Realiza predicciones sobre el conjunto de prueba.
# Calcula al menos una métrica de evaluación (R², MAE o MSE).
# Interpreta el resultado obtenido

# %% [markdown]
# 6. Interpretación
# Explica qué significado tienen los coeficientes del modelo.
# Indica qué variable tiene mayor impacto en el salario según el modelo.
# Comenta una posible limitación del modelo construido.
