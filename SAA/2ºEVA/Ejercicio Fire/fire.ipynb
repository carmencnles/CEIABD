# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

fuego = pd.read_csv("fires-all.csv")

fuego.head(5)
# Out:
#            id  superficie       fecha  lat  lng  latlng_explicit  idcomunidad  \
# 0  1968290001        14.0  1968-01-01  NaN  NaN              NaN            4
# 1  1968430003         3.0  1968-01-03  NaN  NaN              NaN            2
# 2  1968290006         2.0  1968-01-06  NaN  NaN              NaN            4
# 3  1968120007         8.2  1968-01-07  NaN  NaN              NaN            9
# 4  1968430016       600.0  1968-01-07  NaN  NaN              NaN            2
#
#    idprovincia  idmunicipio      municipio  ...  causa_supuesta  causa_desc  \
# 0           29            0  INDETERMINADO  ...               1          40
# 1           43            0  INDETERMINADO  ...               1           0
# 2           29            0  INDETERMINADO  ...               1           0
# 3           12            0  INDETERMINADO  ...               1          20
# 4           43            0  INDETERMINADO  ...               1          20
#
# ...

# %%
fuego_limpio = fuego.drop(['id', 'fecha', 'lat', 'lng', 'latlng_explicit', 'idcomunidad', 'idprovincia', 'idmunicipio', 'municipio', 'causa_supuesta', 'causa_desc', 'time_ctrl', 'time_ext'], axis=1)


fuego_limpio.head()
# Out:
#    superficie  causa  muertos  heridos  personal  medios  gastos  perdidas
# 0        14.0      2        0        0         0       0       0         0
# 1         3.0      5        0        0         0       0       0         0
# 2         2.0      5        0        0         0       0       0         0
# 3         8.2      3        0        0         0       0       0         0
# 4       600.0      3        0        0        35       1       0         0

# %%
fuego_limpio.corr(numeric_only=True)
# Out:
#             superficie     causa   muertos   heridos  personal    medios  \
# superficie    1.000000 -0.018394  0.167830  0.186601  0.439172  0.305015
# causa        -0.018394  1.000000 -0.007382 -0.018564 -0.074774 -0.099698
# muertos       0.167830 -0.007382  1.000000  0.106164  0.084680  0.066929
# heridos       0.186601 -0.018564  0.106164  1.000000  0.247234  0.219242
# personal      0.439172 -0.074774  0.084680  0.247234  1.000000  0.617663
# medios        0.305015 -0.099698  0.066929  0.219242  0.617663  1.000000
# gastos        0.153816 -0.015298  0.043601  0.062579  0.165814  0.178938
# perdidas      0.426223 -0.008382  0.124211  0.240349  0.238585  0.225072
#
#               gastos  perdidas
# superficie  0.153816  0.426223
# causa      -0.015298 -0.008382
# muertos     0.043601  0.124211
# heridos     0.062579  0.240349
# personal    0.165814  0.238585
# medios      0.178938  0.225072
# gastos      1.000000  0.162623
# perdidas    0.162623  1.000000

# %%
import statistics as stat
import seaborn as sns
import matplotlib.pyplot as plt



sns.pairplot(fuego, x_vars=['medios', 'gastos'], y_vars='heridos', height=4, aspect=1, kind='reg')
plt.show()

# %%
sns.pairplot(fuego, x_vars=['medios', 'gastos'], y_vars='muertos', height=4, aspect=1, kind='reg')
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.scatter(fuego['superficie'], fuego['personal'], color='blue', alpha=0.7)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8, 5))

plt.scatter(fuego['perdidas'], fuego['muertos'], color='blue', alpha=0.7)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8, 5))

plt.scatter(fuego['perdidas'], fuego['heridos'], color='blue', alpha=0.7)


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8, 5))

plt.scatter(fuego['superficie'], fuego['perdidas'], color='blue', alpha=0.7)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fuego.corr(numeric_only=True)
# Out:
#                        id  superficie       lat       lng  latlng_explicit  \
# id               1.000000   -0.027643  0.025368  0.058033         0.773499
# superficie      -0.027643    1.000000 -0.040885  0.022654        -0.003164
# lat              0.025368   -0.040885  1.000000 -0.151725        -0.030857
# lng              0.058033    0.022654 -0.151725  1.000000        -0.031658
# latlng_explicit  0.773499   -0.003164 -0.030857 -0.031658         1.000000
# idcomunidad      0.111442    0.020386 -0.188249  0.205732        -0.018805
# idprovincia      0.074023   -0.009877  0.295579 -0.094496        -0.032889
# idmunicipio      0.242536    0.023120 -0.061969  0.241392         0.005247
# causa           -0.099376   -0.018394  0.133317 -0.255736        -0.120973
# causa_supuesta  -0.464722    0.003545  0.084066 -0.155398        -0.313739
# causa_desc      -0.134647    0.008648  0.015293 -0.138124        -0.080231
# ...
